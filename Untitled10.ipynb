# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
df = pd.read_excel("clientes1.xlsx.xlsx", engine='openpyxl')

# %%
print(df.head())
# Out:
#               Jane  (23) 999992787     janeluz323@gmail.com
# 0  Maria de Fatima  (11) 999992787  mariadefatima@gmail.com
# 1      Ana Leticia   (22)562722276  analeticia123@gmail.com

# %%
usuario = 'postgres'
senha = 'sua_senha'
host = 'localhost'
porta = '5432'
banco = 'seu_banco'

# %%
conexao = f'postgresql+psycopg2://{usuario}:{senha}@{host}:{porta}/{banco}'

# %%
engine = create_engine(conexao)

# %%
df.to_excel("clientes_saida.xlsx", index=False, engine='openpyxl')
